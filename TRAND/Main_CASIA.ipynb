# %% [markdown]
# #__Mount GDrive to /content/drive__

# %%
#@markdown <br><center><img src='https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Google_Drive_logo.png/600px-Google_Drive_logo.png' height="50" alt="Gdrive-logo"/></center>
#@markdown <center><h3>Mount GDrive to /content/drive</h3></center><br>
MODE = "MOUNT" #@param ["MOUNT", "UNMOUNT"]
#Mount your Gdrive!
from google.colab import drive
drive.mount._DEBUG = False
if MODE == "MOUNT":
  drive.mount('/content/drive', force_remount=True)
elif MODE == "UNMOUNT":
  try:
    drive.flush_and_unmount()
  except ValueError:
    pass
  get_ipython().system_raw("rm -rf /root/.config/Google/DriveFS")
# Out:
# Mounted at /content/drive

# %%
# !python3 "/content/drive/MyDrive/Junior/IT4432E Biometric/TRAND/GaitSet/train.py" --data "casia-b"
# Out:
# Initialzing...
# Initializing data...
# /content/drive/MyDrive/Junior/IT4432E Biometric/TRAND/data/CASIA-B
# Data initialization complete.
# Initializing model...
# /content/drive/MyDrive/Junior/IT4432E Biometric/TRAND/GaitSet/model/network/basic_blocks.py:36: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   nn.init.xavier_uniform(
# /content/drive/MyDrive/Junior/IT4432E Biometric/TRAND/GaitSet/model/network/gaitset.py:150: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   nn.init.xavier_uniform(m.weight.data)
# ...
# /content/drive/MyDrive/Junior/IT4432E Biometric/TRAND/GaitSet/model/network/basic_blocks.py:36: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   nn.init.xavier_uniform(
# ...

# %%
# !python3 "/content/drive/MyDrive/Junior/IT4432E Biometric/TRAND/main.py" --gpus=0,1,2,3 --load-pretrained=True \
--max-epoch=40 --start-round=1 --max-round=4 \
--loss-init-rate=0.01 --ANs-size=1 \
--source="casia-b" --target="oulp" \
--log-name='CASIA2OULP'
# Out:
# [2024-01-20 16:00:06,900] [INFO]   Start to declare training variables
# [2024-01-20 16:00:06,904] [INFO]   Start to prepare data
# /content/drive/MyDrive/Junior/IT4432E Biometric/TRAND/data/OULP
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# [2024-01-20 16:49:23,105] [INFO]   Totally got 3712 training and 3712 testing samples
# [2024-01-20 16:49:23,105] [INFO]   Start to build model
# ...
